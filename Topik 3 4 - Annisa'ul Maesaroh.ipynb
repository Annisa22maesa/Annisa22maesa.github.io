# %% [markdown]
# ##Topic 3 - Python Structure & Data Type Assignment

# %% [markdown]
# # Data Type Declaration

# %% [markdown]
# 1. > Create an empty variable (Points : 5)

# %%
#Code goes here
namakamu=""
namakamu
# Out:
# ''

# %% [markdown]
# 2. > Create a variable containing your name (Points : 5)

# %%
#Code goes here
namaku="Annisa'ul Maesaroh"
namaku
# Out:
# "Annisa'ul Maesaroh"

# %% [markdown]
# 3. > Create a list of 5 items you can find in the classroom (Points : 5)

# %%
#Code goes here
barang_kelas = ['papan tulis','spidol','meja','kursi','tas']
barang_kelas
# Out:
# ['papan tulis', 'spidol', 'meja', 'kursi', 'tas']

# %% [markdown]
# 4. > Create a dictionary containing 2 keys and value (Points : 5)

# %%
#Code goes here
dataku = {'nama':'Annisa', 'hobi': 'Membaca'}
print("Nama:", dataku['nama'])
print("Hobi:", dataku['hobi'])
# Out:
# Nama: Annisa
# Hobi: Membaca

# %% [markdown]
# # Basic Data Operation

# %% [markdown]
# You sold 20 pieces of electronics at the price of 12000. The customer gets a total discount of 10%.
#
# Below are those variables:
#
# 1.   price=12000
# 2.   quantity_sold=20
# 3.   discount=10%
#
#
# Using Python code, write the code the find the total money that the customer to pay. (Points : 15)

# %%
# identifikasi variabel
price = 12000
quantity_sold = 20
discount = 0.1

tot_price = price * quantity_sold            # hitung total harga sebelum diskon
print("Total harga sebelum diskon: Rp", tot_price)

tot_discount = tot_price * discount          # hitung besarnya diskon
print("Total diskon: Rp", tot_discount)

total = tot_price - tot_discount             # hitung total harga setelah diskon

print("Total yang harus dibayar: Rp", total) # Menampilkan total harga yang harus dibayar oleh pelanggan
# Out:
# Total harga sebelum diskon: Rp 240000
# Total diskon: Rp 24000.0
# Total yang harus dibayar: Rp 216000.0

# %% [markdown]
# # List Data Operation

# %% [markdown]
# 5. > Follow the instructions in the code blocks

# %%
# Create list of countries in the world (total 7 countries) (Points : 5)

kota_dunia = ['Jakarta','Tokyo','Paris','Seoul','Kairo','Sydney','Osaka'] 
kota_dunia
# Out:
# ['Jakarta', 'Tokyo', 'Paris', 'Seoul', 'Kairo', 'Sydney', 'Osaka']

# %%
# Get 4 countries from the first index of the list (Points : 5)

kota_dunia[0:4]
# Out:
# ['Jakarta', 'Tokyo', 'Paris', 'Seoul']

# %%
# Append new country to the list (Points : 5)

kota_dunia.append('London')
kota_dunia
# Out:
# ['Jakarta', 'Tokyo', 'Paris', 'Seoul', 'Kairo', 'Sydney', 'Osaka', 'London']

# %%
# Drop one country from the list (Points : 5)

kota_dunia.remove('Sydney')
kota_dunia
# Out:
# ['Jakarta', 'Tokyo', 'Paris', 'Seoul', 'Kairo', 'Osaka', 'London']

# %%
# Get country in the last index (Points : 5)

last_index = kota_dunia[-1]
last_index
# Out:
# 'London'

# %% [markdown]
# # Dictionary Data Operation

# %% [markdown]
# 6. >  Follow the instructions below

# %%
# Given the dictionary below

customer={
    "name":['Dio','Eka','Wayu','Riki'],
    "age":[20,19,24,39],
    "gender":[1,0,0,1],
    "membership":['Platinum','Gold','Silver','Silver']
}

# %%
# Print all keys in customer (Points : 5)

dict.keys(customer)
# Out:
# dict_keys(['name', 'age', 'gender', 'membership'])

# %%
# Print all customer names (Points : 5)

print(customer['name'])
# Out:
# ['Dio', 'Eka', 'Wayu', 'Riki']

# %%
# Print the first customer name (Points : 5)

print(customer['name'][0])
# Out:
# Dio

# %%
# Drop "age" key from the dictionary (Points : 5)

del customer['age']
customer
# Out:
# {'name': ['Dio', 'Eka', 'Wayu', 'Riki'],
#  'gender': [1, 0, 0, 1],
#  'membership': ['Platinum', 'Gold', 'Silver', 'Silver']}

# %%
# Replace customer gender list value (Points : 20)
# gender 1 => Male
# gender 0 => Female 


for x, gender_value in enumerate(customer['gender']):
    if gender_value == 1:
        customer['gender'][x] = 'Male'
    elif gender_value == 0:
        customer['gender'][x] = 'Female'

print(customer)
# Out:
# {'name': ['Dio', 'Eka', 'Wayu', 'Riki'], 'gender': ['Male', 'Female', 'Female', 'Male'], 'membership': ['Platinum', 'Gold', 'Silver', 'Silver']}
